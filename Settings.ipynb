# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\andre\\JupyterLab'

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 2070'

# %%
torch.cuda.get_device_capability(0)
# Out:
# (7, 5)

# %%
torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 2070', major=7, minor=5, total_memory=8192MB, multi_processor_count=36)

# %%
import fasttext

# %%
import fasttext.util

# %%
fasttext.util.download_model('en', if_exists='ignore')  # English

# %%
fasttext.util.download_model('ru', if_exists='ignore')  # Russian

# %%
# !conda install -y -c conda-forge jupyter-resource-usage
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\andre\anaconda3
#
#   added / updated specs:
#     - jupyter-resource-usage
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa244fe_2         3.1 MB  conda-forge
#     jupyter-resource-usage-0.6.0|     pyhd8ed1ab_0          28 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter-resource-~ conda-forge/noarch::jupyter-resource-usage-0.6.0-pyhd8ed1ab_0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.3-py38haa95532_0 --> conda-forge::conda-4.10.3-py38haa244fe_2
#
#
#
# Downloading and Extracting Packages
#
# jupyter-resource-usa | 28 KB     |            |   0%
# jupyter-resource-usa | 28 KB     | #####6     |  56%
# jupyter-resource-usa | 28 KB     | ########## | 100%
#
# conda-4.10.3         | 3.1 MB    |            |   0%
# conda-4.10.3         | 3.1 MB    | ##9        |  29%
# conda-4.10.3         | 3.1 MB    | ######5    |  66%
# conda-4.10.3         | 3.1 MB    | ########## | 100%
# conda-4.10.3         | 3.1 MB    | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
