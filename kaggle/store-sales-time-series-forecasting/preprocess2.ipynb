# %%
import calendar

import numpy as np
import pandas as pd

# %%
train = pd.read_csv('./data/train.csv', parse_dates=['date'])
test = pd.read_csv('./data/test.csv', parse_dates=['date'])
stores = pd.read_csv('./data/stores.csv')
transactions = pd.read_csv('./data/transactions.csv', parse_dates=['date'])
oil = pd.read_csv('./data/oil.csv', parse_dates=['date'])
holidays = pd.read_csv('./data/holidays_events.csv', parse_dates=['date'])

# %%
data = pd.concat([train, test])

# %%
test_border_date = test.date.unique()[0]

# %%
data.shape
# Out:
# (3029400, 6)

# %%
result0 = data.merge(
    stores,
    on='store_nbr',
)

# %%
result0.shape
# Out:
# (3029400, 10)

# %%
result1 = result0.merge(
    transactions,
    on=['date', 'store_nbr'],
    how='left',
)
result1.shape
# Out:
# (3029400, 11)

# %%
all_dates = sorted(result1.date.unique())

# %%
oil2_data = []
prev_item = None
for oil_date in all_dates:
    oil_item = oil[oil.date == oil_date]
    if oil_item.shape[0] and not np.isnan(oil_item.iloc[0].dcoilwtico):
        oil2_data.append({
            'date': oil_date,
            'oil_price': oil_item.iloc[0].dcoilwtico,
        })
        prev_item = oil_item
    elif prev_item is None:
        x = oil.iloc[1]
        oil2_data.append({
            'date': oil_date,
            'oil_price': x.dcoilwtico,
        })
    else:
        oil2_data.append({
            'date': oil_date,
            'oil_price': prev_item.iloc[0].dcoilwtico,
        })
oil2 = pd.DataFrame(oil2_data)

# %%
oil2.head()
# Out:
#         date  oil_price
# 0 2013-01-01      93.14
# 1 2013-01-02      93.14
# 2 2013-01-03      92.97
# 3 2013-01-04      93.12
# 4 2013-01-05      93.12

# %%
oil2.tail()
# Out:
#            date  oil_price
# 1695 2017-08-27      47.65
# 1696 2017-08-28      46.40
# 1697 2017-08-29      46.46
# 1698 2017-08-30      45.96
# 1699 2017-08-31      47.26

# %%
result2 = result1.merge(
    oil2,
    on='date',
    how='left',
)
result2.shape
# Out:
# (3029400, 12)

# %%
holidays = holidays[(holidays.transferred == False) & (holidays.type != 'Work Day')].copy()
holidays.shape
# Out:
# (333, 6)

# %%
events = holidays[holidays.type == 'Event']
earthquake = events[events.description.str.startswith('Terremoto Manabi')].groupby('date').first()
other_events = events[events.description.str.startswith('Terremoto Manabi') == False].groupby('date').first()

earthquake.rename({'description': 'earthquake'}, axis=1, inplace=True)
other_events.rename({'description': 'event_name'}, axis=1, inplace=True)

print(earthquake.shape)
print(other_events.shape)
# Out:
# (31, 5)
# (25, 5)

# %%
holiday_events = holidays[holidays.type != 'Event']
holiday_events.shape
# Out:
# (277, 6)

# %%
national_events = holiday_events[holiday_events.locale == 'National'].groupby('date').first()
national_events.rename({'description': 'national_holiday'}, axis=1, inplace=True)
national_events.shape
# Out:
# (102, 5)

# %%
regional_events = holiday_events[holiday_events.locale == 'Regional'].groupby('date').first()
regional_events.rename({
    'description': 'regional_holiday',
    'locale_name': 'state',
}, axis=1, inplace=True)
regional_events.shape
# Out:
# (24, 5)

# %%
local_events = holiday_events[holiday_events.locale == 'Local'].groupby('date').first()
local_events.rename({
    'description': 'local_holiday',
    'locale_name': 'city',
}, axis=1, inplace=True)
local_events.shape
# Out:
# (134, 5)

# %%
result3 = result2.merge(
    earthquake[['earthquake']],
    on='date',
    how='left',
).merge(
    other_events[['event_name']],
    on='date',
    how='left',
).merge(
    national_events[['national_holiday']],
    on='date',
    how='left'
).merge(
    regional_events[['regional_holiday', 'state']],
    on=['date', 'state'],
    how='left',
).merge(
    local_events[['local_holiday', 'city']],
    on=['date', 'city'],
    how='left',
)
result3.shape
# Out:
# (3029400, 17)

# %%
result3.earthquake.fillna('', inplace=True)
result3.event_name.fillna('', inplace=True)
result3.national_holiday.fillna('', inplace=True)
result3.regional_holiday.fillna('', inplace=True)
result3.local_holiday.fillna('', inplace=True)

# %%
result3.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion   city      state  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1   1 2013-01-01          1   BABY CARE    0.0            0  Quito  Pichincha
# 2   2 2013-01-01          1      BEAUTY    0.0            0  Quito  Pichincha
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4   4 2013-01-01          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster  transactions  oil_price earthquake event_name  \
# 0    D       13           NaN      93.14
# 1    D       13           NaN      93.14
# 2    D       13           NaN      93.14
# 3    D       13           NaN      93.14
# 4    D       13           NaN      93.14
#
#      national_holiday regional_holiday local_holiday
# 0  Primer dia del ano
# 1  Primer dia del ano
# 2  Primer dia del ano
# 3  Primer dia del ano
# 4  Primer dia del ano

# %%
result3['year'] = result3.date.apply(lambda x: x.year)
result3['month'] = result3.date.apply(lambda x: x.month)
result3['day'] = result3.date.apply(lambda x: x.day)
result3['day_of_week'] = result3.date.apply(lambda x: x.day_of_week)

# %%
result3['eom'] = result3.date.map(lambda x: calendar.monthrange(x.year, x.month)[1])
result3['payday'] = (result3.day == 15) | (result3.day == result3.eom) 
result3.drop('eom', axis=1, inplace=True)

# %%
# %%time
store_numbers = result3.store_nbr.unique()
families = result3.family.unique()
lag_features = 7

result4 = result3.copy()
for store_nbr in store_numbers:
    for family in families:
        cur_idx = (result4.store_nbr == store_nbr) & (result4.family == family)
        for i in range(1, lag_features + 1):
            result4.loc[cur_idx, f'sales_{i}'] = result4.loc[cur_idx, 'sales'].shift(i)
# Out:
# Wall time: 6min 31s

# %%
result4.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion   city      state  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1   1 2013-01-01          1   BABY CARE    0.0            0  Quito  Pichincha
# 2   2 2013-01-01          1      BEAUTY    0.0            0  Quito  Pichincha
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4   4 2013-01-01          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster  ...  day  day_of_week payday sales_1 sales_2 sales_3 sales_4  \
# 0    D       13  ...    1            1  False     NaN     NaN     NaN     NaN
# 1    D       13  ...    1            1  False     NaN     NaN     NaN     NaN
# 2    D       13  ...    1            1  False     NaN     NaN     NaN     NaN
# 3    D       13  ...    1            1  False     NaN     NaN     NaN     NaN
# 4    D       13  ...    1            1  False     NaN     NaN     NaN     NaN
#
#    sales_5  sales_6  sales_7
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN
#
# [5 rows x 29 columns]

# %%
result4[(result4.store_nbr == 1) & (result4.family == 'AUTOMOTIVE')].tail(30)
# Out:
#             id       date  store_nbr      family  sales  onpromotion   city  \
# 55110  2975940 2017-08-02          1  AUTOMOTIVE    4.0            0  Quito
# 55143  2977722 2017-08-03          1  AUTOMOTIVE    3.0            0  Quito
# 55176  2979504 2017-08-04          1  AUTOMOTIVE    8.0            0  Quito
# 55209  2981286 2017-08-05          1  AUTOMOTIVE    5.0            0  Quito
# 55242  2983068 2017-08-06          1  AUTOMOTIVE    6.0            0  Quito
# 55275  2984850 2017-08-07          1  AUTOMOTIVE    7.0            0  Quito
# 55308  2986632 2017-08-08          1  AUTOMOTIVE    4.0            0  Quito
# 55341  2988414 2017-08-09          1  AUTOMOTIVE    7.0            0  Quito
# 55374  2990196 2017-08-10          1  AUTOMOTIVE    9.0            0  Quito
# 55407  2991978 2017-08-11          1  AUTOMOTIVE    1.0            0  Quito
# 55440  2993760 2017-08-12          1  AUTOMOTIVE    6.0            0  Quito
# 55473  2995542 2017-08-13          1  AUTOMOTIVE    1.0            0  Quito
# 55506  2997324 2017-08-14          1  AUTOMOTIVE    1.0            0  Quito
# 55539  2999106 2017-08-15          1  AUTOMOTIVE    4.0            0  Quito
# 55572  3000888 2017-08-16          1  AUTOMOTIVE    NaN            0  Quito
# 55605  3002670 2017-08-17          1  AUTOMOTIVE    NaN            0  Quito
# 55638  3004452 2017-08-18          1  AUTOMOTIVE    NaN            0  Quito
# 55671  3006234 2017-08-19          1  AUTOMOTIVE    NaN            0  Quito
# 55704  3008016 2017-08-20          1  AUTOMOTIVE    NaN            0  Quito
# 55737  3009798 2017-08-21          1  AUTOMOTIVE    NaN            0  Quito
# 55770  3011580 2017-08-22          1  AUTOMOTIVE    NaN            0  Quito
# 55803  3013362 2017-08-23          1  AUTOMOTIVE    NaN            0  Quito
# 55836  3015144 2017-08-24          1  AUTOMOTIVE    NaN            0  Quito
# 55869  3016926 2017-08-25          1  AUTOMOTIVE    NaN            0  Quito
# 55902  3018708 2017-08-26          1  AUTOMOTIVE    NaN            0  Quito
# 55935  3020490 2017-08-27          1  AUTOMOTIVE    NaN            0  Quito
# 55968  3022272 2017-08-28          1  AUTOMOTIVE    NaN            0  Quito
# 56001  3024054 2017-08-29          1  AUTOMOTIVE    NaN            0  Quito
# 56034  3025836 2017-08-30          1  AUTOMOTIVE    NaN            0  Quito
# 56067  3027618 2017-08-31          1  AUTOMOTIVE    NaN            0  Quito
#
#            state type  cluster  ...  day  day_of_week payday sales_1 sales_2  \
# 55110  Pichincha    D       13  ...    2            2  False     5.0     8.0
# 55143  Pichincha    D       13  ...    3            3  False     4.0     5.0
# 55176  Pichincha    D       13  ...    4            4  False     3.0     4.0
# 55209  Pichincha    D       13  ...    5            5  False     8.0     3.0
# 55242  Pichincha    D       13  ...    6            6  False     5.0     8.0
# 55275  Pichincha    D       13  ...    7            0  False     6.0     5.0
# 55308  Pichincha    D       13  ...    8            1  False     7.0     6.0
# 55341  Pichincha    D       13  ...    9            2  False     4.0     7.0
# 55374  Pichincha    D       13  ...   10            3  False     7.0     4.0
# 55407  Pichincha    D       13  ...   11            4  False     9.0     7.0
# 55440  Pichincha    D       13  ...   12            5  False     1.0     9.0
# 55473  Pichincha    D       13  ...   13            6  False     6.0     1.0
# 55506  Pichincha    D       13  ...   14            0  False     1.0     6.0
# 55539  Pichincha    D       13  ...   15            1   True     1.0     1.0
# 55572  Pichincha    D       13  ...   16            2  False     4.0     1.0
# 55605  Pichincha    D       13  ...   17            3  False     NaN     4.0
# 55638  Pichincha    D       13  ...   18            4  False     NaN     NaN
# 55671  Pichincha    D       13  ...   19            5  False     NaN     NaN
# 55704  Pichincha    D       13  ...   20            6  False     NaN     NaN
# 55737  Pichincha    D       13  ...   21            0  False     NaN     NaN
# 55770  Pichincha    D       13  ...   22            1  False     NaN     NaN
# 55803  Pichincha    D       13  ...   23            2  False     NaN     NaN
# 55836  Pichincha    D       13  ...   24            3  False     NaN     NaN
# 55869  Pichincha    D       13  ...   25            4  False     NaN     NaN
# 55902  Pichincha    D       13  ...   26            5  False     NaN     NaN
# 55935  Pichincha    D       13  ...   27            6  False     NaN     NaN
# 55968  Pichincha    D       13  ...   28            0  False     NaN     NaN
# 56001  Pichincha    D       13  ...   29            1  False     NaN     NaN
# 56034  Pichincha    D       13  ...   30            2  False     NaN     NaN
# 56067  Pichincha    D       13  ...   31            3   True     NaN     NaN
#
#       sales_3 sales_4  sales_5  sales_6  sales_7
# 55110     1.0     4.0      7.0      5.0      2.0
# 55143     8.0     1.0      4.0      7.0      5.0
# 55176     5.0     8.0      1.0      4.0      7.0
# 55209     4.0     5.0      8.0      1.0      4.0
# 55242     3.0     4.0      5.0      8.0      1.0
# 55275     8.0     3.0      4.0      5.0      8.0
# 55308     5.0     8.0      3.0      4.0      5.0
# 55341     6.0     5.0      8.0      3.0      4.0
# 55374     7.0     6.0      5.0      8.0      3.0
# 55407     4.0     7.0      6.0      5.0      8.0
# 55440     7.0     4.0      7.0      6.0      5.0
# 55473     9.0     7.0      4.0      7.0      6.0
# 55506     1.0     9.0      7.0      4.0      7.0
# 55539     6.0     1.0      9.0      7.0      4.0
# 55572     1.0     6.0      1.0      9.0      7.0
# 55605     1.0     1.0      6.0      1.0      9.0
# 55638     4.0     1.0      1.0      6.0      1.0
# 55671     NaN     4.0      1.0      1.0      6.0
# 55704     NaN     NaN      4.0      1.0      1.0
# 55737     NaN     NaN      NaN      4.0      1.0
# 55770     NaN     NaN      NaN      NaN      4.0
# 55803     NaN     NaN      NaN      NaN      NaN
# 55836     NaN     NaN      NaN      NaN      NaN
# 55869     NaN     NaN      NaN      NaN      NaN
# 55902     NaN     NaN      NaN      NaN      NaN
# 55935     NaN     NaN      NaN      NaN      NaN
# 55968     NaN     NaN      NaN      NaN      NaN
# 56001     NaN     NaN      NaN      NaN      NaN
# 56034     NaN     NaN      NaN      NaN      NaN
# 56067     NaN     NaN      NaN      NaN      NaN
#
# [30 rows x 29 columns]

# %%
train_result = result3[result3.date < test_border_date].copy()

# %%
test_result = result3[result3.date >= test_border_date].copy()
test_result.drop('sales', axis=1, inplace=True)

# %%
train_result.to_csv('data/train_merged.csv', index=False)

# %%
test_result.to_csv('data/test_merged.csv', index=False)
